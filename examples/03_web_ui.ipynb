# %% [markdown]
# <div align="center">
# <img src="https://raw.githubusercontent.com/MohammedAly22/VoiceTuT-TTS/main/assets/VoiceTut-TTS-Banner.png" width="100%"/>
#
# [![🤗 Model](https://img.shields.io/badge/🤗%20Model-yellow)](https://huggingface.co/mohammedaly22/VoiceTut-TTS) [![🤗 Space](https://img.shields.io/badge/🤗%20Space-blue)](https://huggingface.co/spaces/mohammedaly22/VoiceTut-TTS) [![GitHub](https://img.shields.io/badge/GitHub-181717?logo=github)](https://github.com/MohammedAly22/VoiceTuT-TTS)
# </div>

# %% [markdown]
# # 🌐 VoiceTut-TTS — Gradio Web UI in Colab
#
# Launch the custom-styled Gradio app (speaker dropdown, voice cloning, AR/EN switch). Gradio gives a public `share` link automatically — no tunnel setup needed.

# %%
# !pip install -q git+https://github.com/k2-fsa/OmniVoice.git
# !pip install -q "voicetut-tts[web]"
# !git clone -q https://github.com/MohammedAly22/VoiceTuT-TTS.git || true

# %%
# Launch with a public share link (prints a *.gradio.live URL)
import os
os.environ["OMNICLEO_SHARE"] = "1"
# %run voicetut-tts/app.py

# %% [markdown]
# > The model downloads on first load (a few minutes). When ready, open the **`https://...gradio.live`** link printed above.
